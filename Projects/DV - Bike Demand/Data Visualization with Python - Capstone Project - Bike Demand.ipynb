# %% [markdown]
# ___
#
# <p style="text-align: center;"><img src="https://docs.google.com/uc?id=1lY0Uj5R04yMY3-ZppPWxqCr5pvBLYPnV" class="img-fluid" alt="CLRSWY"></p>
#
# ___

# %% [markdown]
# # WELCOME!

# %% [markdown]
# Welcome to **"Bike Demand Visualization Project"** which is the capstone project of Data Visualization Lessons . As you know recently, free or affordable access to bicycles has been provided for short-distance trips in an urban area as an alternative to motorized public transport or private vehicles. Thus, it is aimed to reduce traffic congestion, noise and air pollution.
#
# The aim of this project is to reveal the current patterns in the data by showing the historical data of London bike shares with visualization tools.
#
# This will allow us to X-ray the data as part of the EDA process before setting up a machine learning model.

# %% [markdown]
# ---
# ---

# %% [markdown]
# # #Determines
#
#
#
# #### Features
#
# - timestamp - timestamp field for grouping the data
# - cnt - the count of a new bike shares
# - t1 - real temperature in C
# - t2 - temperature in C “feels like”
# - hum - humidity in percentage
# - wind_speed - wind speed in km/h
# - weather_code - category of the weather
# - is_holiday - boolean field - 1 holiday / 0 non holiday
# - is_weekend - boolean field - 1 if the day is weekend
# - season - category field meteorological seasons: 0-spring ; 1-summer; 2-fall; 3-winter.
#
# **"weather_code" category description:**
# * 1 = Clear ; mostly clear but have some values with haze/fog/patches of fog/ fog in vicinity
# * 2 = scattered clouds / few clouds
# * 3 = Broken clouds
# * 4 = Cloudy
# * 7 = Rain/ light Rain shower/ Light rain
# * 10 = rain with thunderstorm
# * 26 = snowfall
# * 94 = Freezing Fog
# ---
#
# Initially, the task of discovering data will be waiting for you as always. Recognize features, detect missing values, outliers etc.  Review the data from various angles in different time breakdowns. For example, visualize the distribution of bike shares by day of the week. With this graph, you will be able to easily observe and make inferences how people's behavior changes daily. Likewise, you can make hourly, monthly, seasonally etc. analyzes. In addition, you can analyze correlation of variables with a heatmap.

# %% [markdown]
# # Tasks

# %% [markdown]
# ### 1.Import libraries

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from pandas.plotting import register_matplotlib_converters
from pylab import rcParams
sns.set_style("darkgrid")

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ### 2.Read dataset

# %%
df=pd.read_csv('bike_demand.csv')
df.head()
# Out:
#              timestamp  cnt   t1   t2    hum  wind_speed  weather_code  \
# 0  2015-01-04 00:00:00  182  3.0  2.0   93.0         6.0           3.0
# 1  2015-01-04 01:00:00  138  3.0  2.5   93.0         5.0           1.0
# 2  2015-01-04 02:00:00  134  2.5  2.5   96.5         0.0           1.0
# 3  2015-01-04 03:00:00   72  2.0  2.0  100.0         0.0           1.0
# 4  2015-01-04 04:00:00   47  2.0  0.0   93.0         6.5           1.0
#
#    is_holiday  is_weekend  season
# 0         0.0         1.0     3.0
# 1         0.0         1.0     3.0
# 2         0.0         1.0     3.0
# 3         0.0         1.0     3.0
# 4         0.0         1.0     3.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17414 entries, 0 to 17413
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   timestamp     17414 non-null  object
#  1   cnt           17414 non-null  int64
#  2   t1            17414 non-null  float64
#  3   t2            17414 non-null  float64
#  4   hum           17414 non-null  float64
#  5   wind_speed    17414 non-null  float64
#  6   weather_code  17414 non-null  float64
#  7   is_holiday    17414 non-null  float64
#  8   is_weekend    17414 non-null  float64
#  9   season        17414 non-null  float64
# dtypes: float64(8), int64(1), object(1)
# memory usage: 1.3+ MB

# %% [markdown]
# ### 3.Check missing values and if there are any dublicate rows or not.

# %%
df.duplicated().value_counts()
# Out:
# False    17414
# dtype: int64

# %%
df.isnull().sum()
# Out:
# timestamp       0
# cnt             0
# t1              0
# t2              0
# hum             0
# wind_speed      0
# weather_code    0
# is_holiday      0
# is_weekend      0
# season          0
# dtype: int64

# %% [markdown]
# ### 4.Plot the distribution of various discrete features on (Season, haliday, weekend and weathercode)

# %%
df.head()
# Out:
#              timestamp  cnt   t1   t2    hum  wind_speed  weather_code  \
# 0  2015-01-04 00:00:00  182  3.0  2.0   93.0         6.0           3.0
# 1  2015-01-04 01:00:00  138  3.0  2.5   93.0         5.0           1.0
# 2  2015-01-04 02:00:00  134  2.5  2.5   96.5         0.0           1.0
# 3  2015-01-04 03:00:00   72  2.0  2.0  100.0         0.0           1.0
# 4  2015-01-04 04:00:00   47  2.0  0.0   93.0         6.5           1.0
#
#    is_holiday  is_weekend  season
# 0         0.0         1.0     3.0
# 1         0.0         1.0     3.0
# 2         0.0         1.0     3.0
# 3         0.0         1.0     3.0
# 4         0.0         1.0     3.0

# %%
# season 0-spring, 1-summer, 2-fall, 3-winter
plt.figure(figsize=(9,5))
ax = sns.countplot(x=df.season)

ax.set(ylim=(0,4500))
plt.xticks([0, 1, 2, 3], ['Spring', 'Summer', 'Fall', 'Winter']);

# %%
# is_holiday
plt.figure(figsize=(9,5))
ax = sns.countplot(x=df.is_holiday)


plt.xticks([0,1],['Not Holiday','Holiday'])
plt.show()

# %%
# is_weekend
plt.figure(figsize=(9,5))
ax = sns.countplot(x=df.is_weekend)
plt.xticks([0, 1], ['Weekdays', 'Weekend']);

# %%
# weather_code
ax=sns.countplot("weather_code", data=df);
plt.title("WEATHER SITUATION", color = "blue", fontsize=14)

# Style
plt.xticks([-0.3,0.5,1.5,2.8,3.8,4.1,5.6],
           ['Clear', 'Few Clouds', 'Broken Clouds',"Cloudy", "Rainy", "Rain w_Thunderstorm", "Snowfall"],
          rotation=45,fontsize=12)
ax.set_xlabel('Weather',fontsize=15)
ax.set_ylabel('Count',fontsize=15)

#Print count numbers on top of the graph bars
for p in ax.patches:
    ax.annotate( str(p.get_height()),  (p.get_x()+0.2, p.get_height()+20) );

# %% [markdown]
# ### 5.Look at the data type of each variable, transform `timestamp` in type, and set it as index.

# %%
df.timestamp = pd.to_datetime(df.timestamp)
df.set_index('timestamp',inplace=True)

# %% [markdown]
# - Tam 2 yillik bir timestamp var. `year, month, day_of_month, day_of_week, hour` bilgilerini alarak feature engineering yapalim

# %% [markdown]
# ### 6.Make feature engineering. Extract new columns (day of the week, day of the month, hour, month, season, year etc.)

# %% [markdown]
# you can use strftime('%Y-%m') for year_mount

# %%
from datetime import datetime as dt
df['year'] = df.index.year
df['month'] = df.index.month
df['day_of_month'] = df.index.day
df['day_of_week'] = df.index.dayofweek
df['hour'] = df.index.hour
df['year_month'] = df.index.strftime('%Y-%m')
df.head()
# Out:
#                      cnt   t1   t2    hum  wind_speed  weather_code  \
# timestamp
# 2015-01-04 00:00:00  182  3.0  2.0   93.0         6.0           3.0
# 2015-01-04 01:00:00  138  3.0  2.5   93.0         5.0           1.0
# 2015-01-04 02:00:00  134  2.5  2.5   96.5         0.0           1.0
# 2015-01-04 03:00:00   72  2.0  2.0  100.0         0.0           1.0
# 2015-01-04 04:00:00   47  2.0  0.0   93.0         6.5           1.0
#
#                      is_holiday  is_weekend  season  year  month  \
# timestamp
# 2015-01-04 00:00:00         0.0         1.0     3.0  2015      1
# 2015-01-04 01:00:00         0.0         1.0     3.0  2015      1
# 2015-01-04 02:00:00         0.0         1.0     3.0  2015      1
# 2015-01-04 03:00:00         0.0         1.0     3.0  2015      1
# 2015-01-04 04:00:00         0.0         1.0     3.0  2015      1
#
#                      day_of_month  day_of_week  hour year_month
# timestamp
# 2015-01-04 00:00:00             4            6     0    2015-01
# 2015-01-04 01:00:00             4            6     1    2015-01
# 2015-01-04 02:00:00             4            6     2    2015-01
# 2015-01-04 03:00:00             4            6     3    2015-01
# 2015-01-04 04:00:00             4            6     4    2015-01

# %%
# Example check the type of column contents
type(df.day_of_month[0])
# Out:
# numpy.int64

# %% [markdown]
# ### 7.Visualize the correlation with a heatmap

# %%
plt.figure(figsize=(15,9))
sns.heatmap(data=df.corr(),
            annot=True, 
            cmap='Greens');

# %%
# for the target variable

plt.figure(figsize=(2,7))

#Some checks
# df.corr()
# sns.heatmap(df.corr()[['cnt']])
# sns.heatmap(df.corr()[['cnt']],vmin=-1,vmax=1,annot=True)

df_cnt = df.corr()[['cnt']].sort_values(by='cnt',ascending=False)
sns.heatmap(df_cnt, 
            vmin=-1, 
            vmax=1, 
            annot=True, 
            cmap='coolwarm')

# Show
plt.show()

# %% [markdown]
# ### 8. Visualize the correlation of the target variable and the other features with barplot

# %%
#with pandas

df_cnt.plot.barh(figsize=(10,6),
                 legend=False,
                 fontsize=12).invert_yaxis();

# %% [markdown]
# ### 9.Plot bike shares over time use lineplot

# %%
# df.head()
plt.figure(figsize=(15,6))
ax=sns.lineplot(x=df.index,y=df.cnt)

#Style
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
ax.set_xlabel('Timestamp',fontsize=15)
ax.set_ylabel('Count',fontsize=15)

# Show
plt.show()

# %% [markdown]
# ### 10.Plot bike shares by months and year_of_month (use lineplot, pointplot, barplot)

# %%
df_month = df.groupby('year_month').sum()
df_month.head()
# Out:
#                cnt       t1      t2       hum  wind_speed  weather_code  \
# year_month
# 2015-01     546639   4101.0  2255.5  51005.00    12502.00        2211.0
# 2015-02     543594   3721.5  1868.0  51950.00     9873.50        2409.0
# 2015-03     695934   6093.5  4558.5  51832.25    12938.25        1940.0
# 2015-04     831582   7873.0  7112.5  48468.00    10988.50        1642.0
# 2015-05     895413  10091.5  9803.5  47939.00    14268.50        1900.0
#
#             is_holiday  is_weekend  season     year  month  day_of_month  \
# year_month
# 2015-01            0.0       192.0  2013.0  1352065    671         11753
# 2015-02            0.0       192.0  2013.0  1352065   1342          9734
# 2015-03            0.0       215.0     0.0  1489085   2217         11751
# 2015-04           48.0       191.0     0.0  1448785   2876         11156
# 2015-05           48.0       240.0     0.0  1499160   3720         11904
#
#             day_of_week  hour
# year_month
# 2015-01            2014  7709
# 2015-02            2015  7707
# 2015-03            2174  8540
# 2015-04            2131  8270
# 2015-05            2376  8556

# %%
# with lineplot
plt.figure(figsize=(20,6))
ax=sns.lineplot(x=df_month.index,y=df_month.cnt)

#Style
plt.xticks(rotation=90,fontsize=12)
plt.yticks(fontsize=12)
ax.set_xlabel('Year-Month',fontsize=15)
ax.set_ylabel('Count',fontsize=15)

#Show
plt.show()

# %%
# with lineplot
plt.figure(figsize=(16,7))
ax=sns.lineplot(x=df.month,y=df.cnt)

#Style
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
ax.set_xlabel('Month',fontsize=15)
ax.set_ylabel('Count',fontsize=15)

#Show
plt.show()

# %%
# with pointplot
plt.figure(figsize=(16,5))
ax=sns.pointplot(x=df.month,y=df.cnt)

#Style
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
ax.set_xlabel('Month',fontsize=15)
ax.set_ylabel('Count',fontsize=15)

#Show
plt.show()

# %%
# with barplot
plt.figure(figsize=(10,5))
ax=sns.barplot(x=df.month,y=df.cnt)

#Style
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
ax.set_xlabel('Month',fontsize=15)
ax.set_ylabel('Count',fontsize=15)

#Show
plt.show()

# %% [markdown]
# ### 11.Plot bike shares by hours on (holidays, weekend, season)

# %%
# with lineplot (*whether it is a holiday or not*)
plt.figure(figsize=(20,5))
ax=sns.lineplot(x=df.hour,y=df.cnt,hue=df.is_holiday)

#Style
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
ax.set_xlabel('Hour',fontsize=15)
ax.set_ylabel('Count',fontsize=15)

#Show
plt.show()

# %%
# with lineplot (*You may want to see seasonal breakdowns*)
plt.figure(figsize=(20,5))
ax=sns.lineplot(x=df.hour,y=df.cnt,hue=df.season)

#Style
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
ax.set_xlabel('Hour',fontsize=15)
ax.set_ylabel('Count',fontsize=15)

#Show
plt.show()

# %%
# with pointplot
fig,(ax1,ax2,ax3,ax4) = plt.subplots(nrows=4,figsize=(17,16))

sns.pointplot(x='hour',y='cnt',data=df,ax=ax1)
sns.pointplot(x='hour',y='cnt',data=df,hue='is_holiday',ax=ax2)
sns.pointplot(x='hour',y='cnt',data=df,hue='is_weekend',ax=ax3)
sns.pointplot(x='hour',y='cnt',data=df,hue='season',ax=ax4)

#Show
plt.show()

# %% [markdown]
# ### 12.Plot bike shares by day of week
# - You may want to see whether it is a holiday or not

# %%
plt.figure(figsize=(10,5))
ax=sns.barplot(x=df.day_of_week,y=df.cnt,hue=df.is_weekend)

#Style
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
ax.set_xlabel('Day of Week',fontsize=15)
ax.set_ylabel('Count',fontsize=15)

#Show
plt.show()

# %%
# with pointplot
fig, (ax1,ax2) = plt.subplots(nrows=2,figsize=(15,8))

ax1=sns.pointplot(x=df.day_of_week,y=df.cnt,ax=ax1)
ax2=sns.pointplot(x=df.day_of_week,y=df.cnt,hue=df.season,ax=ax2)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)

plt.show()

# %% [markdown]
# ### 13.Plot bike shares by day of month

# %%
plt.figure(figsize=(15,5))
ax=sns.lineplot(x='day_of_month',y='cnt',data=df)

#Style
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
ax.set_xlabel('Day of Month',fontsize=15)
ax.set_ylabel('Count',fontsize=15)

#Show
plt.show()

# %% [markdown]
# ### 14.Plot bike shares by year
# ### Plot bike shares on holidays by seasons

# %%
plt.figure(figsize=(10,6))
ax=sns.barplot(x='year',y='cnt',data=df)

#Style
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
ax.set_xlabel('Year',fontsize=15)
ax.set_ylabel('Count',fontsize=15)

#Show
plt.show()

# %%
# with barplot
plt.figure(figsize=(10,6))

#On holidays filter.
ax=sns.barplot(x='season',y='cnt',data=df[df['is_holiday']==1])

#Style
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
ax.set_xlabel('Season',fontsize=15)
ax.set_ylabel('Count',fontsize=15)

#Show
plt.show()

# %% [markdown]
# ### 15.Visualize the distribution of bike shares by weekday/weekend with piechart and barplot

# %%
df.is_weekend.value_counts()
# Out:
# 0.0    12444
# 1.0     4970
# Name: is_weekend, dtype: int64

# %%
plt.figure(figsize=(8,6))
x=['Weekday','Weekend']

plt.pie(x=df.is_weekend.value_counts(),labels=x,autopct='%.2f',pctdistance=0.5)
plt.show()
# df.is_weekend.value_counts().plot.pie(autopct="%.2f");

# %%
# with countplot
plt.figure(figsize=(8,6))

ax=sns.countplot(x='is_weekend',data=df)

#Style
plt.xticks([0.0,1.0],['Weekday', 'Weekend'],fontsize=12)
plt.yticks(fontsize=12)
ax.set_xlabel('Is weekend?',fontsize=15)
ax.set_ylabel('Count',fontsize=15)

#Print the percentages and the count numbers on top of the bars
for i in ax.patches:
    ax.annotate(str(round(i.get_height()/len(df)*100,1))+"% - "+str(i.get_height()),(i.get_x()+0.25,i.get_height()+20),size=12)


#Show
plt.show()

# %% [markdown]
# ### 16.Plot the distribution of weather code by seasons

# %%
# with countplot
plt.figure(figsize=(8,6))

ax=sns.countplot(x='weather_code',data=df)

#Style
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
ax.set_xlabel('Weather Code',fontsize=15)
ax.set_ylabel('Count',fontsize=15)

#Show
plt.show()

# %%
# with catplot
sns.catplot(x='weather_code',data=df,col='season',kind='count',ci=0);

# %% [markdown]
# ___
#
# <p style="text-align: center;"><img src="https://docs.google.com/uc?id=1lY0Uj5R04yMY3-ZppPWxqCr5pvBLYPnV" class="img-fluid" alt="CLRSWY"></p>
#
# ___
